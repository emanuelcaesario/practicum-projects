# %% [markdown]
# # Movie Sentiment Analysis

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#1-Project-Description" data-toc-modified-id="1-Project-Description-1">1 Project Description</a></span><ul class="toc-item"><li><span><a href="#1.1-Data-Description" data-toc-modified-id="1.1-Data-Description-1.1">1.1 Data Description</a></span></li><li><span><a href="#1.2-Stages-of-Project-Completion" data-toc-modified-id="1.2-Stages-of-Project-Completion-1.2">1.2 Stages of Project Completion</a></span></li></ul></li><li><span><a href="#2-Data-Pre-processing" data-toc-modified-id="2-Data-Pre-processing-2">2 Data Pre-processing</a></span><ul class="toc-item"><li><span><a href="#2.1-Import-Libraries" data-toc-modified-id="2.1-Import-Libraries-2.1">2.1 Import Libraries</a></span></li><li><span><a href="#2.2-Load-and-Read-the-Data" data-toc-modified-id="2.2-Load-and-Read-the-Data-2.2">2.2 Load and Read the Data</a></span></li></ul></li><li><span><a href="#3-Exploratory-Data-Analysis" data-toc-modified-id="3-Exploratory-Data-Analysis-3">3 Exploratory Data Analysis</a></span></li><li><span><a href="#4-Evaluation-Procedure" data-toc-modified-id="4-Evaluation-Procedure-4">4 Evaluation Procedure</a></span></li><li><span><a href="#5-Normalization" data-toc-modified-id="5-Normalization-5">5 Normalization</a></span></li><li><span><a href="#6-Train-and-Test-Split" data-toc-modified-id="6-Train-and-Test-Split-6">6 Train and Test Split</a></span></li><li><span><a href="#7-Work-with-Models" data-toc-modified-id="7-Work-with-Models-7">7 Work with Models</a></span><ul class="toc-item"><li><span><a href="#7.1-Model-0---Constant" data-toc-modified-id="7.1-Model-0---Constant-7.1">7.1 Model 0 - Constant</a></span></li><li><span><a href="#7.2-Model-1---NLTK-Logistic-Regression" data-toc-modified-id="7.2-Model-1---NLTK-Logistic-Regression-7.2">7.2 Model 1 - NLTK Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#7.2.1-Implementing-TF-IDF-Method-with-NTLK-Preprocessing" data-toc-modified-id="7.2.1-Implementing-TF-IDF-Method-with-NTLK-Preprocessing-7.2.1">7.2.1 Implementing TF-IDF Method with NTLK Preprocessing</a></span></li><li><span><a href="#7.2.2-Create-Model-1" data-toc-modified-id="7.2.2-Create-Model-1-7.2.2">7.2.2 Create Model 1</a></span></li><li><span><a href="#7.2.3-Testing-Model-1-on-New-Test-Data" data-toc-modified-id="7.2.3-Testing-Model-1-on-New-Test-Data-7.2.3">7.2.3 Testing Model 1 on New Test Data</a></span></li></ul></li><li><span><a href="#7.3-Model-2---spaCy-Logistic-Regression" data-toc-modified-id="7.3-Model-2---spaCy-Logistic-Regression-7.3">7.3 Model 2 - spaCy Logistic Regression</a></span><ul class="toc-item"><li><span><a href="#7.3.1-Implementing-TF-IDF-Method-with-spaCy-Preprocessing" data-toc-modified-id="7.3.1-Implementing-TF-IDF-Method-with-spaCy-Preprocessing-7.3.1">7.3.1 Implementing TF-IDF Method with spaCy Preprocessing</a></span></li><li><span><a href="#7.3.2-Create-Model-2" data-toc-modified-id="7.3.2-Create-Model-2-7.3.2">7.3.2 Create Model 2</a></span></li><li><span><a href="#7.3.3-Testing-Model-2-on-New-Test-Data" data-toc-modified-id="7.3.3-Testing-Model-2-on-New-Test-Data-7.3.3">7.3.3 Testing Model 2 on New Test Data</a></span></li></ul></li><li><span><a href="#7.4-Model-3---NLTK-LGBMClassifier" data-toc-modified-id="7.4-Model-3---NLTK-LGBMClassifier-7.4">7.4 Model 3 - NLTK LGBMClassifier</a></span><ul class="toc-item"><li><span><a href="#7.4.1-Create-Model-3" data-toc-modified-id="7.4.1-Create-Model-3-7.4.1">7.4.1 Create Model 3</a></span></li><li><span><a href="#7.4.2-Testing-Model-3-on-New-Test-Data" data-toc-modified-id="7.4.2-Testing-Model-3-on-New-Test-Data-7.4.2">7.4.2 Testing Model 3 on New Test Data</a></span></li></ul></li><li><span><a href="#7.5-Model-4---spaCy-LGBMClassifier" data-toc-modified-id="7.5-Model-4---spaCy-LGBMClassifier-7.5">7.5 Model 4 - spaCy LGBMClassifier</a></span><ul class="toc-item"><li><span><a href="#7.5.1-Create-Model-4" data-toc-modified-id="7.5.1-Create-Model-4-7.5.1">7.5.1 Create Model 4</a></span></li><li><span><a href="#7.5.2-Testing-Model-4-on-New-Test-Data" data-toc-modified-id="7.5.2-Testing-Model-4-on-New-Test-Data-7.5.2">7.5.2 Testing Model 4 on New Test Data</a></span></li></ul></li><li><span><a href="#7.6-Model-5---NLTK-XGBoost-Classifier" data-toc-modified-id="7.6-Model-5---NLTK-XGBoost-Classifier-7.6">7.6 Model 5 - NLTK XGBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#7.6.1-Create-Model-5" data-toc-modified-id="7.6.1-Create-Model-5-7.6.1">7.6.1 Create Model 5</a></span></li><li><span><a href="#7.6.2-Testing-Model-5-on-New-Test-Data" data-toc-modified-id="7.6.2-Testing-Model-5-on-New-Test-Data-7.6.2">7.6.2 Testing Model 5 on New Test Data</a></span></li></ul></li><li><span><a href="#7.7-Model-6---spaCy-XGBoost-Classifier" data-toc-modified-id="7.7-Model-6---spaCy-XGBoost-Classifier-7.7">7.7 Model 6 - spaCy XGBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#7.7.1-Create-Model-6" data-toc-modified-id="7.7.1-Create-Model-6-7.7.1">7.7.1 Create Model 6</a></span></li><li><span><a href="#7.7.2-Testing-Model-6-on-New-Test-Data" data-toc-modified-id="7.7.2-Testing-Model-6-on-New-Test-Data-7.7.2">7.7.2 Testing Model 6 on New Test Data</a></span></li></ul></li><li><span><a href="#7.8-Model-7---NLTK-CatBoost-Classifier" data-toc-modified-id="7.8-Model-7---NLTK-CatBoost-Classifier-7.8">7.8 Model 7 - NLTK CatBoost Classifier</a></span><ul class="toc-item"><li><span><a href="#7.8.1-Create-Model-7" data-toc-modified-id="7.8.1-Create-Model-7-7.8.1">7.8.1 Create Model 7</a></span></li><li><span><a href="#7.8.2-Testing-Model-7-on-New-Test-Data" data-toc-modified-id="7.8.2-Testing-Model-7-on-New-Test-Data-7.8.2">7.8.2 Testing Model 7 on New Test Data</a></span></li></ul></li></ul></li><li><span><a href="#8-Conclusion" data-toc-modified-id="8-Conclusion-8">8 Conclusion</a></span></li></ul></div>

# %% [markdown]
# ## 1 Project Description

# %% [markdown]
# Film Junky Union, a new community for classic film fans, is currently developing a system to filter and categorize movie reviews. The objective is to train a model capable of automatically detecting negative reviews. Our task is to utilize the IMBD film review dataset with polarity labeling and create a model that can accurately classify positive and negative reviews. The set goal for this model is to achieve an F1 score of at least 0.85.

# %% [markdown]
# ### 1.1 Data Description

# %% [markdown]
# The data is stored in the file `imdb_reviews.tsv`.
#
# This dataset was obtained from Andrew L. Maas, Raymond E. Daly, Peter T. Pham, Dan Huang, Andrew Y. Ng, and Christopher Potts. (2011). Learning Word Vectors for Sentiment Analysis. The 49th Annual Meeting of the Association for Computational Linguistics (ACL 2011).
#
# Here are the descriptions for the selected columns:
# - `review` — review text
# - `pos` — target, '0' for negative and '1' for positive
# - `ds_part` — 'train'/'test' for the train/test part of the dataset
#
# These three columns are the main focus of our attention in this task. However, it is worth noting that there are also other columns present in the dataset.

# %% [markdown]
# ### 1.2 Stages of Project Completion

# %% [markdown]
# This project will be completed through the following stages:
#
# 1. Loading and studying the data.
# 2. Performing initial data pre-processing.
# 3. Conducting exploratory data analysis (EDA) and addressing class imbalances.
# 4. Performing data pre-processing to prepare the data for modeling.
# 5. Training at least three models using the existing training dataset.
# 6. Evaluating the models on the existing test dataset.
# 7. Writing additional reviews and classifying them using all models.
# 8. Analyzing and comparing the model test results from the two points above, and providing an explanation for the observed differences.

# %% [markdown]
# ## 2 Data Pre-processing

# %% [markdown]
# ### 2.1 Import Libraries

# %%
import math

import numpy as np
import pandas as pd

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

import sklearn.metrics as metrics
from sklearn.dummy import DummyClassifier
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

import re
import spacy

from lightgbm import LGBMClassifier
from xgboost import XGBClassifier
from catboost import CatBoostClassifier

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %config InlineBackend.figure_format = 'png'

# Better quality graphics on HiDPI screens
# %config InlineBackend.figure_format = 'retina'

plt.style.use('seaborn')

# %% [markdown]
# ### 2.2 Load and Read the Data

# %%
# Load the data
df_reviews = pd.read_csv('imdb_reviews.tsv', sep='\t', dtype={'votes': 'Int64'})

# %%
# Check data sample 
df_reviews.sample(5)
# Out:
#           tconst title_type    primary_title   original_title  start_year  \
# 16166  tt0411475      movie        Hell Ride        Hell Ride        2008
# 34176  tt0213446      movie  The Amati Girls  The Amati Girls        2000
# 43415  tt0762073      movie           Thirst           Bakjwi        2009
# 26159  tt0098084      movie     Pet Sematary     Pet Sematary        1989
# 28063  tt0780595      movie          Redline          Redline        2007
#
#       end_year runtime_minutes  is_adult                 genres  \
# 16166       \N              84         0  Action,Drama,Thriller
# 34176       \N              91         0                  Drama
# 43415       \N             134         0   Drama,Fantasy,Horror
# 26159       \N             103         0        Horror,Thriller
# 28063       \N              95         0                 Action
#
#        average_rating  votes  \
# 16166             5.1  15274
# 34176             5.3    354
# 43415             7.1  41141
# ...

# %%
# Read the general information
print('Data Description')
display(df_reviews.describe(include='all').T)
print('='*120)
print('='*120)
print('General Information')
display(df_reviews.info())
# Out:
# Data Description
#                    count unique  \
# tconst             47331   6648
# title_type         47331     10
# primary_title      47331   6555
# original_title     47331   6562
# start_year       47331.0    NaN
# end_year           47331     60
# runtime_minutes    47331    249
# is_adult         47331.0    NaN
# genres             47331    585
# average_rating   47329.0    NaN
# votes            47329.0    NaN
# review             47331  47240
# rating           47331.0    NaN
# sp                 47331      2
# pos              47331.0    NaN
# ds_part            47331      2
# idx              47331.0    NaN
#
#                                                                top   freq  \
# tconst                                                   tt0067445     30
# title_type                                                   movie  36861
# primary_title                                         The Sentinel     60
# ...

# %% [markdown]
# **Findings:**
# - The dataset contains a total of 17 columns and 47,311 rows of data.
# - Two data rows have missing values in the `average_rating` and `votes` columns, which will be removed.
# - The majority of columns are categorical and are of type "object" (10 columns).
# - The movie data spans from the year 1894 to 2010.
# - The average value of the `average_rating` column is approximately 6, with a median of 6.3. The lowest rating is 1.4, and the highest is 9.7.
# - The mean of the `rating` column is 5.484608, but the median is 4.0, indicating the presence of an outlier.
# - The dataset includes mixed train and test data, identified in the `ds_part` column.
# - Overall, the data quality is considered to be good enough.

# %%
# Delete rows with missing values
df_reviews = df_reviews.dropna()
df_reviews.isna().sum()
# Out:
# tconst             0
# title_type         0
# primary_title      0
# original_title     0
# start_year         0
# end_year           0
# runtime_minutes    0
# is_adult           0
# genres             0
# average_rating     0
# votes              0
# review             0
# rating             0
# sp                 0
# pos                0
# ds_part            0
# idx                0
# dtype: int64

# %% [markdown]
# ## 3 Exploratory Data Analysis

# %% [markdown]
# We will conduct an exploratory data analysis to gain insights into the overall trends in this dataset. Our analysis will involve examining the number of films and reviews over the years, exploring the distribution of the number of reviews per film, and evaluating the class balance within the data.

# %%
# Check the number of movies and reviews over the years
fig, axs = plt.subplots(2, 1, figsize=(16, 8))

ax = axs[0]

dft1 = df_reviews[['tconst', 'start_year']].drop_duplicates() \
    ['start_year'].value_counts().sort_index()
dft1 = dft1.reindex(index=np.arange(dft1.index.min(), max(dft1.index.max(), 2011))).fillna(0)
dft1.plot(kind='bar', ax=ax)
ax.set_title('Number of Movies Over the Years')

ax = axs[1]

dft2 = df_reviews.groupby(['start_year', 'pos'])['pos'].count().unstack()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2011))).fillna(0)

dft2.plot(kind='bar', stacked=True, label='Review  (neg, pos)', ax=ax)

dft2 = df_reviews['start_year'].value_counts().sort_index()
dft2 = dft2.reindex(index=np.arange(dft2.index.min(), max(dft2.index.max(), 2011))).fillna(0)
dft3 = (dft2/dft1).fillna(0)
axt = ax.twinx()
dft3.reset_index(drop=True).rolling(5).mean().plot(color='orange', 
                                                   label='Reviews per film (5 years average)', ax=axt)

lines1, labels1 = ax.get_legend_handles_labels()
lines2, labels2 = axt.get_legend_handles_labels()
ax.legend(lines1 + lines2, labels1 + labels2, loc='upper left')

ax.set_title('Number of Reviews Over Years') 

fig.tight_layout()

# %% [markdown]
# **Findings:**
# - The number of films has been steadily increasing over the past decade.
# - There was a decline in the number of films during the 1960s, but since the 1970s, there has been a significant increase.
# - Film production shows a decline after 2007, but this could be due to data collection deadlines.
# - The trend of the number of reviews also follows the pattern of the number of films over the years.
# - However, there was not a significant surge in the number of reviews during the 1990s and 2000s, despite the rapid increase in the number of films during that period.

# %% [markdown]
# Next, we will analyze the distribution of the number of reviews per film with precise counts. Additionally, we will utilize KDE (Kernel Density Estimation) plots to visualize the differences from the exact calculations. The KDE plot provides a representation of the probability density of a random variable.

# %%
# Check the distribution of the number of reviews per film
fig, axs = plt.subplots(1, 2, figsize=(16, 5))

ax = axs[0]
dft = df_reviews.groupby('tconst')['review'].count() \
    .value_counts() \
    .sort_index()
dft.plot.bar(ax=ax)
ax.set_title('Bar Plot for #Review Per Film')

ax = axs[1]
dft = df_reviews.groupby('tconst')['review'].count()
sns.kdeplot(dft, ax=ax)
ax.set_title('KDE Plot #Review Per Film') 

fig.tight_layout()

# %% [markdown]
# The majority of films receive a limited number of reviews, with less than 5 reviews. However, there is also a considerable number of films that have reviews ranging up to 30.
#
# Next, we will assess the class balance in the `pos` column to compare the proportion of positive and negative reviews in the data. As you are aware, a value of '0' represents negative reviews, while '1' represents positive reviews.

# %%
# Counts the number of unique values
value_counts = df_reviews['pos'].value_counts()

# Calculates the proportion of unique values
value_props = round(df_reviews['pos'].value_counts(normalize=True) * 100, 2).astype('str') + '%'

# Merge results into a DataFrame
df_pos = pd.DataFrame({'total': value_counts, 'percentage': value_props})

# Show the DataFrame
df_pos
# Out:
#    total percentage
# 0  23715     50.11%
# 1  23614     49.89%

# %% [markdown]
# In general, the dataset is evenly divided between positive and negative reviews, with a slightly higher number of negative reviews. Next, we will analyze the balance in the distribution of ratings on both the train and test datasets, as identified in the `ds_part` column.

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 4))

ax = axs[0]
dft = df_reviews.query('ds_part == "train"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('Train set: rank distribution')

ax = axs[1]
dft = df_reviews.query('ds_part == "test"')['rating'].value_counts().sort_index()
dft = dft.reindex(index=np.arange(min(dft.index.min(), 1), max(dft.index.max(), 11))).fillna(0)
dft.plot.bar(ax=ax)
ax.set_ylim([0, 5000])
ax.set_title('Test set: rank distribution')

fig.tight_layout()

# %% [markdown]
# The rating distribution between the train set and the test set is quite similar. Next, we will investigate the distribution of negative and positive reviews over the years for both parts of the dataset.

# %%
# Distribution of negative and positive reviews per year for two parts of the dataset
fig, axs = plt.subplots(2, 2, figsize=(16, 8), gridspec_kw=dict(width_ratios=(2, 1), height_ratios=(1, 1)))

ax = axs[0][0]

dft = df_reviews.query('ds_part == "train"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2011))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('Train set: number of reviews of different polarity per year')
ax.set_xticks(range(0, len(dft.index), 5))
ax.set_xticklabels(dft.index[::5])

ax = axs[0][1]

dft = df_reviews.query('ds_part == "train"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('Train set: different polarity distribution per film')

ax = axs[1][0]

dft = df_reviews.query('ds_part == "test"').groupby(['start_year', 'pos'])['pos'].count().unstack()
dft.index = dft.index.astype('int')
dft = dft.reindex(index=np.arange(dft.index.min(), max(dft.index.max(), 2011))).fillna(0)
dft.plot(kind='bar', stacked=True, ax=ax)
ax.set_title('Test set: number of reviews of different polarity per year')
ax.set_xticks(range(0, len(dft.index), 5))
ax.set_xticklabels(dft.index[::5])

ax = axs[1][1]

dft = df_reviews.query('ds_part == "test"').groupby(['tconst', 'pos'])['pos'].count().unstack()
sns.kdeplot(dft[0], color='blue', label='negative', kernel='epa', ax=ax)
sns.kdeplot(dft[1], color='green', label='positive', kernel='epa', ax=ax)
ax.legend()
ax.set_title('Test set: different polarity distribution per film')

fig.tight_layout()

# %% [markdown]
# The rating distribution on both datasets is quite similar. For the majority of films with limited reviews, negative ratings tend to dominate. However, for films with a higher number of reviews, positive ratings become more prevalent.

# %% [markdown]
# ## 4 Evaluation Procedure

# %% [markdown]
# Perform regular evaluations for all models in this task to generate useful insights and assess their performance effectively.

# %%
# Define evaluation function
def evaluate_model(model, features_train, target_train, features_test, target_test):
    
    eval_stats = {}
    
    fig, axs = plt.subplots(1, 3, figsize=(20, 6)) 
    
    for type, features, target in (('train', features_train, target_train), ('test', features_test, target_test)):
        
        eval_stats[type] = {}
    
        pred_target = model.predict(features)
        pred_proba = model.predict_proba(features)[:, 1]
        
        # F1
        f1_thresholds = np.arange(0, 1.01, 0.05)
        f1_scores = [metrics.f1_score(target, pred_proba>=threshold) for threshold in f1_thresholds]
        
        # ROC
        fpr, tpr, roc_thresholds = metrics.roc_curve(target, pred_proba)
        roc_auc = metrics.roc_auc_score(target, pred_proba)    
        eval_stats[type]['ROC AUC'] = roc_auc

        # PRC
        precision, recall, pr_thresholds = metrics.precision_recall_curve(target, pred_proba)
        aps = metrics.average_precision_score(target, pred_proba)
        eval_stats[type]['APS'] = aps
        
        if type == 'train':
            color = 'blue'
        else:
            color = 'green'

        # Scor F1 
        ax = axs[0]
        max_f1_score_idx = np.argmax(f1_scores)
        ax.plot(f1_thresholds, f1_scores, 
                color=color, label=f'{type}, max={f1_scores[max_f1_score_idx]:.2f} @ {f1_thresholds[max_f1_score_idx]:.2f}')
        # set crosses for multiple thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(f1_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(f1_thresholds[closest_value_idx], f1_scores[closest_value_idx], 
                    color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('threshold')
        ax.set_ylabel('F1')
        ax.legend(loc='lower center')
        ax.set_title(f'Skor F1') 

        # ROC
        ax = axs[1]    
        ax.plot(fpr, tpr, color=color, label=f'{type}, ROC AUC={roc_auc:.2f}')
        # set crosses for multiple thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(roc_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'            
            ax.plot(fpr[closest_value_idx], tpr[closest_value_idx], color=marker_color, marker='X', markersize=7)
        ax.plot([0, 1], [0, 1], color='grey', linestyle='--')
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('FPR')
        ax.set_ylabel('TPR')
        ax.legend(loc='lower center')        
        ax.set_title(f'Kurva ROC')
        
        # PRC
        ax = axs[2]
        ax.plot(recall, precision, color=color, label=f'{type}, AP={aps:.2f}')
        # set crosses for multiple thresholds
        for threshold in (0.2, 0.4, 0.5, 0.6, 0.8):
            closest_value_idx = np.argmin(np.abs(pr_thresholds-threshold))
            marker_color = 'orange' if threshold != 0.5 else 'red'
            ax.plot(recall[closest_value_idx], precision[closest_value_idx], 
                    color=marker_color, marker='X', markersize=7)
        ax.set_xlim([-0.02, 1.02])    
        ax.set_ylim([-0.02, 1.02])
        ax.set_xlabel('recall')
        ax.set_ylabel('precision')
        ax.legend(loc='lower center')
        ax.set_title(f'PRC')        

        eval_stats[type]['Accuracy'] = metrics.accuracy_score(target, pred_target)
        eval_stats[type]['F1'] = metrics.f1_score(target, pred_target)
    
    df_eval_stats = pd.DataFrame(eval_stats)
    df_eval_stats = df_eval_stats.round(2)
    df_eval_stats = df_eval_stats.reindex(index=('Accuracy', 'F1', 'APS', 'ROC AUC'))
    
    return df_eval_stats

# %% [markdown]
# ## 5 Normalization

# %% [markdown]
# We assume that all models below are designed to handle text in lowercase and without numbers, punctuation, and other special characters.

# %%
# Make all reviews into lowercase
df_reviews['review_norm'] = df_reviews['review'].str.lower()

# Removes numbers, punctuation and characters other than letters and spaces
df_reviews['review_norm'] = df_reviews['review_norm'].apply(lambda x: re.sub(r'[^a-z\s]', '', x))

# %%
# Check and compare the results
df_reviews[['review','review_norm']]
# Out:
#                                                   review  \
# 0      The pakage implies that Warren Beatty and Gold...
# 1      How the hell did they get this made?! Presenti...
# 2      There is no real story the film seems more lik...
# 3      Um .... a serious film about troubled teens in...
# 4      I'm totally agree with GarryJohal from Singapo...
# ...                                                  ...
# 47326  This is another of my favorite Columbos. It sp...
# 47327  Talk about being boring! I got this expecting ...
# 47328  I never thought I'd say this about a biopic, b...
# 47329  Spirit and Chaos is an artistic biopic of Miya...
# 47330  I'll make this brief. This was a joy to watch....
#
#                                              review_norm
# 0      the pakage implies that warren beatty and gold...
# 1      how the hell did they get this made presenting...
# 2      there is no real story the film seems more lik...
# ...

# %% [markdown]
# All reviews have been successfully converted to lowercase and contain only letters and spaces, with any other characters removed.

# %% [markdown]
# ## 6 Train and Test Split

# %% [markdown]
# All datasets have been labeled for training and testing purposes. The information about the dataset split is indicated in the `ds_part` column. We will now divide this dataset into two groups, namely train and test, based on the labels in the `ds_part` column.

# %%
# Create two new datasets for train and test
df_reviews_train = df_reviews.query('ds_part == "train"')
df_reviews_test = df_reviews.query('ds_part == "test"')

features_train = df_reviews_train.drop('pos', axis=1)
target_train = df_reviews_train['pos']

features_test = df_reviews_test.drop('pos', axis=1)
target_test = df_reviews_test['pos']

print(features_train.shape)
print(features_test.shape)
# Out:
# (23796, 17)
# (23533, 17)

# %% [markdown]
# ## 7 Work with Models

# %% [markdown]
# Now is the time to train a machine learning model for sentiment analysis on the existing dataset. We will employ various machine learning training models to compare their accuracy scores and identify the best-performing model.
#
# To establish a benchmark, we will use the constant model, where the model predicts a single value, specifically 1. A more sophisticated model should surpass the baseline model's performance.

# %% [markdown]
# ### 7.1 Model 0 - Constant

# %%
# Implementing the DummyClassifier model with a `constant` strategy
model_0 = DummyClassifier(strategy='constant', constant=1).fit(features_train, target_train)

model_0_score = evaluate_model(model_0, features_train, target_train, features_test, target_test)
model_0_score
# Out:
#           train  test
# Accuracy   0.50  0.50
# F1         0.67  0.67
# APS        0.50  0.50
# ROC AUC    0.50  0.50

# %% [markdown]
# ### 7.2 Model 1 - NLTK Logistic Regression

# %% [markdown]
# We will test several models using the TF-IDF (Term Frequency - Inverse Document Frequency) method, which is a common technique in natural language processing to evaluate the importance of words in a document.
#
# This method calculates the frequency of a word in a document (TF) and how frequently the word occurs across documents in a dataset (IDF).
#
# In the future, we will switch between using the NLTK (Natural Language Toolkit) and SpaCy libraries to support natural language processing (NLP). We will implement different TF-IDF methods for these two libraries.
#
# For this initial model, we will utilize NLTK to support the Logistic Regression model.

# %% [markdown]
# #### 7.2.1 Implementing TF-IDF Method with NTLK Preprocessing

# %%
# Perform text pre-processing with NLTK

nltk.download('punkt')
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ebcae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ebcae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Tokenize and lematize loops on the `review_norm` column for training
features_train_nltk = []
for text in features_train['review_norm']:
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    join = " ".join(lemmas)
    features_train_nltk.append(join)

# %%
# Tokenize and lematize loops on the `review_norm` column for testing
features_test_nltk = []
for text in features_test['review_norm']:
    tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(token) for token in tokens]
    join = " ".join(lemmas)
    features_test_nltk.append(join)

# %%
# Applying the TF-IDF method and removing stop words
nltk.download('stopwords')
tf_idf = TfidfVectorizer(stop_words='english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ebcae\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### 7.2.2 Create Model 1

# %%
# Create new features by implementing TF-IDF
features_train_1 = tf_idf.fit_transform(features_train_nltk)
features_test_1 = tf_idf.transform(features_test_nltk)

# %%
# Create a Logistic Regression model without tuning hyperparameters
model_1 = LogisticRegression().fit(features_train_1, target_train)

# %%
# Conduct model evaluation
model_1_score = evaluate_model(model_1, features_train_1, target_train, features_test_1, target_test)
model_1_score
# Out:
#           train  test
# Accuracy   0.94  0.87
# F1         0.94  0.87
# APS        0.98  0.95
# ROC AUC    0.98  0.95

# %% [markdown]
# This model gives a pretty good score, much higher than the base model.

# %% [markdown]
# #### 7.2.3 Testing Model 1 on New Test Data

# %% [markdown]
# Now, we will test the model that has been developed on a new dataset containing new reviews. We will present 10 random reviews, equally divided between positive and negative. The model will provide probability scores for these reviews.
#
# A probability score closer to 1 indicates that the review is positive, while a score closer to 0 indicates that the review is negative.
#
# This evaluation approach will be applied to future models as well.

# %%
# Creates a new dataframe for testing containing 10 movie review lines
# Positive and negative reviews are alternated, with the first review being negative

my_reviews = pd.DataFrame([
    "This movie was an absolute waste of time. I wouldn't recommend it to anyone.",
    "I was thoroughly impressed with this film. The storyline was engaging and the acting was superb.",
    "I found this movie to be incredibly boring. It just didn't hold my attention.",
    "The special effects in this movie were out of this world. Definitely worth watching.",
    "I was disappointed by this film. It didn't live up to the hype.",
    "This movie was a masterpiece. I was blown away by the stunning visuals and emotional storyline.",
    "I thought the acting in this movie was terrible. It was hard to watch.",
    "I couldn't take my eyes off the screen. This movie had me on the edge of my seat from start to finish.",
    "The dialogue in this movie was so cheesy. I couldn't take it seriously.",
    "I loved this film. It had all the right elements to make a great movie.",
], columns=['review'])

my_reviews['review_norm'] = my_reviews['review'].str.lower().apply(lambda x: re.sub(r'[^a-z\s]', '', x))

my_reviews
# Out:
#                                               review  \
# 0  This movie was an absolute waste of time. I wo...
# 1  I was thoroughly impressed with this film. The...
# 2  I found this movie to be incredibly boring. It...
# 3  The special effects in this movie were out of ...
# 4  I was disappointed by this film. It didn't liv...
# 5  This movie was a masterpiece. I was blown away...
# 6  I thought the acting in this movie was terribl...
# 7  I couldn't take my eyes off the screen. This m...
# 8  The dialogue in this movie was so cheesy. I co...
# 9  I loved this film. It had all the right elemen...
#
#                                          review_norm
# 0  this movie was an absolute waste of time i wou...
# 1  i was thoroughly impressed with this film the ...
# 2  i found this movie to be incredibly boring it ...
# 3  the special effects in this movie were out of ...
# 4  i was disappointed by this film it didnt live ...
# 5  this movie was a masterpiece i was blown away ...
# ...

# %%
# Calculates the probability score based on the model
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_1.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.05:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.84:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.05:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.97:  the special effects in this movie were out of this world definitely worth watching
# 0.16:  i was disappointed by this film it didnt live up to the hype
# 0.86:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.08:  i thought the acting in this movie was terrible it was hard to watch
# 0.71:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.15:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 1.00:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# This model exhibits a distinct contrast in probability values between negative and positive reviews. In the first row, which represents a negative review, the probability value is very close to 0, while in the second row, which corresponds to a positive review, the probability is very close to 1.

# %% [markdown]
# ### 7.3 Model 2 - spaCy Logistic Regression

# %% [markdown]
# We will follow the same steps as the first model, but this time, we will use the spaCy library for natural language processing (NLP).

# %% [markdown]
# #### 7.3.1 Implementing TF-IDF Method with spaCy Preprocessing

# %%
# Perform text pre-processing using spaCy
# Make English models into nlp variables
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# We use an alternative way this time
# Instead of looping, we define a function to lematize and remove stop words
def text_preprocessing(text):
    doc = nlp(text)
    tokens = [token.lemma_ for token in doc if not token.is_stop]
        
    return ' '.join(tokens)

# %%
# Create a new feature by implementing the function earlier
features_train_spacy = features_train['review_norm'].apply(lambda x: text_preprocessing(x))
features_test_spacy = features_test['review_norm'].apply(lambda x: text_preprocessing(x))

# %%
# Implementing the TF-IDF method
tf_idf_2 = TfidfVectorizer()
features_train_2 = tf_idf_2.fit_transform(features_train_spacy)
features_test_2 = tf_idf_2.transform(features_test_spacy)

# %% [markdown]
# #### 7.3.2 Create Model 2

# %%
# Create a Logistic Regression model without tuning hyperparameters
model_2 = LogisticRegression().fit(features_train_2, target_train)

# %%
# Conduct model evaluation
model_2_score = evaluate_model(model_2, features_train_2, target_train, features_test_2, target_test)
model_2_score
# Out:
#           train  test
# Accuracy   0.93  0.87
# F1         0.93  0.87
# APS        0.98  0.94
# ROC AUC    0.98  0.95

# %% [markdown]
# Overall, the score is not significantly better than the previous model.

# %% [markdown]
# #### 7.3.3 Testing Model 2 on New Test Data

# %%
# Calculates the probability score based on the model
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_2.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.05:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.76:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.09:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.96:  the special effects in this movie were out of this world definitely worth watching
# 0.25:  i was disappointed by this film it didnt live up to the hype
# 0.85:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.03:  i thought the acting in this movie was terrible it was hard to watch
# 0.67:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.08:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 1.00:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# This model also performs well in making predictions with distinct differences in probabilities.
#
# Similar to the first model, this second model accurately predicts the positive probability in the 10th line, which contains the word 'love'.

# %% [markdown]
# ### 7.4 Model 3 - NLTK LGBMClassifier

# %% [markdown]
# Now, we will proceed with trying the gradient boosting model, LightGBM Classifier. Once more, we will utilize the TF-IDF method with NLP from the NLTK library.

# %% [markdown]
# #### 7.4.1 Create Model 3

# %%
# Create new features, apply the TF-IDF method, and remove stop words
features_train_3 = tf_idf.fit_transform(features_train_nltk)
features_test_3 = tf_idf.transform(features_test_nltk)

# %%
# Create a LightGBM Classifier model without tuning hyperparameters
model_3 = LGBMClassifier().fit(features_train_3, target_train)

# %%
# Conduct model evaluation
model_3_score = evaluate_model(model_3, features_train_3, target_train, features_test_3, target_test)
model_3_score
# Out:
#           train  test
# Accuracy   0.91  0.86
# F1         0.91  0.86
# APS        0.97  0.93
# ROC AUC    0.97  0.93

# %% [markdown]
# It performs no better than Model 1 and Model 2 in terms of scoring.

# %% [markdown]
# #### 7.4.2 Testing Model 3 on New Test Data

# %%
# Calculates the probability score based on the model
my_reviews_pred_prob = model_3.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.10:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.84:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.14:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.88:  the special effects in this movie were out of this world definitely worth watching
# 0.55:  i was disappointed by this film it didnt live up to the hype
# 0.81:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.16:  i thought the acting in this movie was terrible it was hard to watch
# 0.71:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.61:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.92:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Although not as precise as the previous two models, it still demonstrates good capability in distinguishing between positive and negative reviews.
#
# However, in the 5th line review, the model incorrectly rates the negative review as positive with a 55 percent probability. The same thing happens in the 9th row. While this probability difference is relatively small, if the threshold is set at 50 percent, then this prediction would be incorrect.

# %% [markdown]
# ### 7.5 Model 4 - spaCy LGBMClassifier

# %% [markdown]
# We will once again develop a LightGBM Classifier model, but this time, we will utilize spaCy's TF-IDF and NLP methods.

# %% [markdown]
# #### 7.5.1 Create Model 4

# %%
# Create new features and implement TF-IDF methods
features_train_4 = tf_idf_2.fit_transform(features_train_spacy)
features_test_4 = tf_idf_2.transform(features_test_spacy)

# %%
# Create a LightGBM Classifier model without tuning hyperparameters
model_4 = LGBMClassifier().fit(features_train_4, target_train)

# %%
# Conduct model evaluation
model_4_score = evaluate_model(model_4, features_train_4, target_train, features_test_4, target_test)
model_4_score
# Out:
#           train  test
# Accuracy   0.91  0.85
# F1         0.91  0.85
# APS        0.97  0.93
# ROC AUC    0.97  0.93

# %% [markdown]
# The score actually shows a decline.

# %% [markdown]
# #### 7.5.2 Testing Model 4 on New Test Data

# %%
# Calculates the probability score based on the model
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_4.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.09:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.82:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.13:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.88:  the special effects in this movie were out of this world definitely worth watching
# 0.43:  i was disappointed by this film it didnt live up to the hype
# 0.75:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.15:  i thought the acting in this movie was terrible it was hard to watch
# 0.44:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.40:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.94:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Overall, this model also performs well in predictions, although it exhibits an error in the 8th line.

# %% [markdown]
# ### 7.6 Model 5 - NLTK XGBoost Classifier

# %% [markdown]
# This time, we will implement the next gradient boosting model, the XGBoost Classifier.

# %% [markdown]
# #### 7.6.1 Create Model 5

# %%
# Create new features, apply the TF-IDF method, and remove stop words
features_train_5 = tf_idf.fit_transform(features_train_nltk)
features_test_5 = tf_idf.transform(features_test_nltk)

# %%
# Create a XGBoost Classifier model without tuning hyperparameters
model_5 = XGBClassifier().fit(features_train_5, target_train)

# %%
# Conduct model evaluation
model_5_score = evaluate_model(model_5, features_train_5, target_train, features_test_5, target_test)
model_5_score
# Out:
#           train  test
# Accuracy   0.94  0.85
# F1         0.94  0.85
# APS        0.99  0.92
# ROC AUC    0.99  0.93

# %% [markdown]
# We obtained a better score than Model 1 for the training set, but the score for the test set is still slightly lower than Model 1.

# %% [markdown]
# #### 7.6.2 Testing Model 5 on New Test Data

# %%
# Calculates the probability score based on the model
my_reviews_pred_prob = model_5.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.13:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.83:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.23:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.85:  the special effects in this movie were out of this world definitely worth watching
# 0.57:  i was disappointed by this film it didnt live up to the hype
# 0.65:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.26:  i thought the acting in this movie was terrible it was hard to watch
# 0.59:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.56:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.83:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# Overall, this model does not perform well in making predictions. The errors are evident in the 5th and 9th rows. Additionally, the probability difference between positive and negative ratings is not distinct. Most probability values lie in the middle, indicating that the model cannot predict with certainty.

# %% [markdown]
# ### 7.7 Model 6 - spaCy XGBoost Classifier

# %% [markdown]
# We will use the XGBoost Classifier again, but this time with spaCy for Natural Language Processing (NLP).

# %% [markdown]
# #### 7.7.1 Create Model 6

# %%
# Create new features and implement TF-IDF methods
features_train_6 = tf_idf_2.fit_transform(features_train_spacy)
features_test_6 = tf_idf_2.transform(features_test_spacy)

# %%
# Create a XGBoost Classifier model without tuning hyperparameters
model_6 = XGBClassifier().fit(features_train_6, target_train)

# %%
# Conduct model evaluation
model_6_score = evaluate_model(model_6, features_train_6, target_train, features_test_6, target_test)
model_6_score
# Out:
#           train  test
# Accuracy   0.94  0.84
# F1         0.94  0.85
# APS        0.99  0.92
# ROC AUC    0.99  0.93

# %% [markdown]
# The results are no better than the Model 5.

# %% [markdown]
# #### 7.7.2 Testing Model 6 on New Test Data

# %%
# Calculates the probability score based on the model
texts = my_reviews['review_norm']

my_reviews_pred_prob = model_6.predict_proba(tf_idf_2.transform(texts.apply(lambda x: text_preprocessing(x))))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.11:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.79:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.21:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.84:  the special effects in this movie were out of this world definitely worth watching
# 0.47:  i was disappointed by this film it didnt live up to the hype
# 0.79:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.24:  i thought the acting in this movie was terrible it was hard to watch
# 0.47:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.47:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.94:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# This model also exhibits less precision in making predictions. The model is unable to correctly classify the 8th row.

# %% [markdown]
# ### 7.8 Model 7 - NLTK CatBoost Classifier

# %% [markdown]
# Now, it's time to use the CatBoost Classifier. Up until now, the NLTK library has performed better than spaCy. Therefore, for this model, we will exclusively use NLTK.

# %% [markdown]
# #### 7.8.1 Create Model 7

# %%
# Create new features, apply the TF-IDF method, and remove stop words
features_train_7 = tf_idf.fit_transform(features_train_nltk)
features_test_7 = tf_idf.transform(features_test_nltk)

# %%
# Create CatBoost Classifier models without tuning hyperparameters
model_7 = CatBoostClassifier(verbose=500).fit(features_train_7, target_train)
# Out:
# Learning rate set to 0.039875
# 0:	learn: 0.6814313	total: 2.35s	remaining: 39m 5s
# 500:	learn: 0.3288095	total: 6m 41s	remaining: 6m 39s
# 999:	learn: 0.2582800	total: 13m 16s	remaining: 0us

# %%
# Conduct model evaluation
model_7_score = evaluate_model(model_7, features_train_7, target_train, features_test_7, target_test)
model_7_score
# Out:
#           train  test
# Accuracy   0.92  0.86
# F1         0.92  0.86
# APS        0.98  0.94
# ROC AUC    0.98  0.94

# %% [markdown]
# So far, Model 1 remains the best-performing model.

# %% [markdown]
# #### 7.8.2 Testing Model 7 on New Test Data

# %%
# Calculates the probability score based on the model
my_reviews_pred_prob = model_7.predict_proba(tf_idf.transform(texts))[:, 1]

for i, review in enumerate(texts.str.slice(0, 100)):
    print(f'{my_reviews_pred_prob[i]:.2f}:  {review}')
# Out:
# 0.21:  this movie was an absolute waste of time i wouldnt recommend it to anyone
# 0.76:  i was thoroughly impressed with this film the storyline was engaging and the acting was superb
# 0.25:  i found this movie to be incredibly boring it just didnt hold my attention
# 0.79:  the special effects in this movie were out of this world definitely worth watching
# 0.55:  i was disappointed by this film it didnt live up to the hype
# 0.73:  this movie was a masterpiece i was blown away by the stunning visuals and emotional storyline
# 0.32:  i thought the acting in this movie was terrible it was hard to watch
# 0.61:  i couldnt take my eyes off the screen this movie had me on the edge of my seat from start to finish
# 0.56:  the dialogue in this movie was so cheesy i couldnt take it seriously
# 0.89:  i loved this film it had all the right elements to make a great movie

# %% [markdown]
# This model also lacks precision in providing probability values. There is an error in line 5 and 9.

# %% [markdown]
# ## 8 Conclusion

# %% [markdown]
# We have tested 7 different models in the current analysis. Overall, all models provided an F1 score above 0.85, as expected by this task. However, there are variations in quality among the models.
#
# Model 1, which was trained using Logistic Regression with the TF-IDF method and the NLTK library for NLP, delivered the best overall score. It achieved an F1 score of 0.88 on the test data.

# %%
# Unify model variables into one dataframe
all_score = pd.concat([model_0_score, model_1_score, model_2_score, model_3_score, 
                       model_4_score, model_5_score, model_6_score, model_6_score], axis=1)

# Changing indexes to column names and changing columns to rows
all_score = all_score.T.rename_axis('model').set_index(
    pd.Index(['model_0_train', 'model_0_test', 'model_1_train', 'model_1_test',
              'model_2_train', 'model_2_test', 'model_3_train', 'model_3_test', 
              'model_4_train', 'model_4_test', 'model_5_train', 'model_5_test',
              'model_6_train', 'model_6_test', 'model_7_train', 'model_7_test']))
model_name = ['Konstan', '^', 'NLTK LR', '^', 'spaCy LR', '^',  'NLTK LGBM', '^', 
              'spaCy LGBM', '^', 'NLTK XGBoost', '^', 'spaCy XGBoost', '^', 
             'NLTK Catboost', '^']
all_score.insert(0, 'Model', model_name)
all_score
# Out:
#                        Model  Accuracy    F1   APS  ROC AUC
# model_0_train        Konstan      0.50  0.67  0.50     0.50
# model_0_test               ^      0.50  0.67  0.50     0.50
# model_1_train        NLTK LR      0.94  0.94  0.98     0.98
# model_1_test               ^      0.87  0.87  0.95     0.95
# model_2_train       spaCy LR      0.93  0.93  0.98     0.98
# model_2_test               ^      0.87  0.87  0.94     0.95
# model_3_train      NLTK LGBM      0.91  0.91  0.97     0.97
# model_3_test               ^      0.86  0.86  0.93     0.93
# model_4_train     spaCy LGBM      0.91  0.91  0.97     0.97
# model_4_test               ^      0.85  0.85  0.93     0.93
# model_5_train   NLTK XGBoost      0.94  0.94  0.99     0.99
# model_5_test               ^      0.85  0.85  0.92     0.93
# model_6_train  spaCy XGBoost      0.94  0.94  0.99     0.99
# model_6_test               ^      0.84  0.85  0.92     0.93
# model_7_train  NLTK Catboost      0.94  0.94  0.99     0.99
# ...

# %% [markdown]
# # Checklist

# %% [markdown]
# - [x] Notebook opened successfully.
# - [x] Text data has been loaded and pre-processed for vectorization.
# - [x] Text data has been successfully converted to vectors.
# - [x] The model has been trained and tested.
# - [x] The metric threshold has been achieved.
# - [x] All cell codes are arranged in the correct execution order.
# - [x] All cell codes can be executed without any errors.
# - [x] A conclusion has been provided.
