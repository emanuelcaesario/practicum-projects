# %% [markdown]
# # Analisis Harga Kendaraan Bekas

# %% [markdown]
# <h1>~ Daftar Isi ~<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Pengantar" data-toc-modified-id="Pengantar-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pengantar</a></span><ul class="toc-item"><li><span><a href="#Latar-Belakang-dan-Tujuan" data-toc-modified-id="Latar-Belakang-dan-Tujuan-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Latar Belakang dan Tujuan</a></span></li><li><span><a href="#Deskripsi-Data" data-toc-modified-id="Deskripsi-Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Deskripsi Data</a></span></li></ul></li><li><span><a href="#Pra-pemrosesan" data-toc-modified-id="Pra-pemrosesan-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Pra-pemrosesan</a></span><ul class="toc-item"><li><span><a href="#Import-Library" data-toc-modified-id="Import-Library-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Import Library</a></span></li><li><span><a href="#Memuat-Data" data-toc-modified-id="Memuat-Data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Memuat Data</a></span></li><li><span><a href="#Mengeksplorasi-Data-Awal" data-toc-modified-id="Mengeksplorasi-Data-Awal-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Mengeksplorasi Data Awal</a></span></li><li><span><a href="#Mengatasi-Nilai-Nilai-yang-Hilang" data-toc-modified-id="Mengatasi-Nilai-Nilai-yang-Hilang-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Mengatasi Nilai-Nilai yang Hilang</a></span></li><li><span><a href="#Memperbaiki-Tipe-Data" data-toc-modified-id="Memperbaiki-Tipe-Data-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Memperbaiki Tipe Data</a></span></li><li><span><a href="#Memperbaiki-Kualitas-Data" data-toc-modified-id="Memperbaiki-Kualitas-Data-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Memperbaiki Kualitas Data</a></span></li><li><span><a href="#Memeriksa-Data-yang-Sudah-Bersih" data-toc-modified-id="Memeriksa-Data-yang-Sudah-Bersih-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>Memeriksa Data yang Sudah Bersih</a></span></li></ul></li><li><span><a href="#Analisis-Data-Eksploratif" data-toc-modified-id="Analisis-Data-Eksploratif-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Analisis Data Eksploratif</a></span><ul class="toc-item"><li><span><a href="#Mempelajari-Parameter-Inti" data-toc-modified-id="Mempelajari-Parameter-Inti-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Mempelajari Parameter Inti</a></span></li><li><span><a href="#Mempelajari-dan-Menangani-Outlier" data-toc-modified-id="Mempelajari-dan-Menangani-Outlier-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Mempelajari dan Menangani Outlier</a></span></li><li><span><a href="#Mempelajari-Parameter-Inti-Tanpa-Outlier" data-toc-modified-id="Mempelajari-Parameter-Inti-Tanpa-Outlier-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Mempelajari Parameter Inti Tanpa Outlier</a></span></li><li><span><a href="#Masa-Berlaku-Iklan" data-toc-modified-id="Masa-Berlaku-Iklan-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Masa Berlaku Iklan</a></span></li><li><span><a href="#Harga-Rata-Rata-Setiap-Jenis-Kendaraan" data-toc-modified-id="Harga-Rata-Rata-Setiap-Jenis-Kendaraan-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Harga Rata-Rata Setiap Jenis Kendaraan</a></span></li><li><span><a href="#Faktor-Harga" data-toc-modified-id="Faktor-Harga-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Faktor Harga</a></span><ul class="toc-item"><li><span><a href="#Sedan" data-toc-modified-id="Sedan-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Sedan</a></span></li><li><span><a href="#SUV" data-toc-modified-id="SUV-3.6.2"><span class="toc-item-num">3.6.2&nbsp;&nbsp;</span>SUV</a></span></li></ul></li></ul></li><li><span><a href="#Kesimpulan-Umum" data-toc-modified-id="Kesimpulan-Umum-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Kesimpulan Umum</a></span></li></ul></div>

# %% [markdown]
# ## Pengantar

# %% [markdown]
# ### Latar Belakang dan Tujuan

# %% [markdown]
# Analisis kali ini bertujuan untuk menyelidiki faktor-faktor yang mempengaruhi harga jual mobil di pasar kendaraan bekas. Untuk itu, kami telah dibekali data puluhan ribu iklan kendaraan yang ditayangkan secara gratis di web Crankshaft List dalam beberapa tahun terakhir.
#
# Kami akan terlebih dahulu melakukan pra-pemrosesan atas data yang ada, membersihkan, memperbaiki, dan melengkapinya agar menjadi lebih bersih dan dapat memberikan insight yang jernih. Berangkat dari situ, kami akan menganalisis faktor-faktor yang mempengaruhi harga jual kendaraan bekas.

# %% [markdown]
# ### Deskripsi Data

# %% [markdown]
# Kami mendapatkan dataset `vehicles_us.csv` yang berisi kolom-kolom berikut:
#
#
# - `price` — harga jual kendaraan
# - `model_year` — tahun pembuatan kendaraan
# - `model` — jenis kendaraan
# - `condition` — kondisi kendaraan
# - `cylinders` — jenis atau jumlah silinder kendaraan
# - `fuel` — gas, disel, dan lain-lain.
# - `odometer` — jarak tempuh kendaraan saat iklan ditayangkan
# - `transmission` — jenis transmisi kendaraan
# - `paint_color` — warna kendaraan
# - `is_4wd` — apakah kendaraan memiliki penggerak 4 roda (tipe Boolean)
# - `date_posted` — tanggal iklan ditayangkan
# - `days_listed` — jumlah hari iklan ditayangkan hingga dihapus

# %% [markdown]
# ## Pra-pemrosesan

# %% [markdown]
# ### Import Library

# %% [markdown]
# Kami akan menggunakan beberapa library Phyton untuk analisis ini. Kami mulai dengan mengimpor beberapa library penting.

# %%
# Muat semua library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Memuat Data

# %% [markdown]
# Sekarang kami akan memuat data yang tersedia pada dataset yang kami dapatkan dan memahami kolom-kolomnya.

# %%
# Muat file data ke dalam dataframe
path = 'vehicles_us.csv'
df = pd.read_csv(path)

# Memeriksa sampel data
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
# Memeriksa format penulisan kolom
df.columns
# Out:
# Index(['price', 'model_year', 'model', 'condition', 'cylinders', 'fuel',
#        'odometer', 'transmission', 'type', 'paint_color', 'is_4wd',
#        'date_posted', 'days_listed'],
#       dtype='object')

# %%
# Memeriksa ukuran data
df.shape
# Out:
# (51525, 13)

# %% [markdown]
# Data berhasil dibuka tanpa masalah. Kami memiliki 51.525 baris data dalam 13 kolom. Tidak terdapat masalah dalam format penulisan kolom.

# %% [markdown]
# ### Mengeksplorasi Data Awal

# %%
# Memeriksa informasi umum pada data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %%
# Memeriksa deskripsi data numerik
df.describe()
# Out:
#                price    model_year     cylinders       odometer   is_4wd  \
# count   51525.000000  47906.000000  46265.000000   43633.000000  25572.0
# mean    12132.464920   2009.750470      6.125235  115553.461738      1.0
# std     10040.803015      6.282065      1.660360   65094.611341      0.0
# min         1.000000   1908.000000      3.000000       0.000000      1.0
# 25%      5000.000000   2006.000000      4.000000   70000.000000      1.0
# 50%      9000.000000   2011.000000      6.000000  113000.000000      1.0
# 75%     16839.000000   2014.000000      8.000000  155000.000000      1.0
# max    375000.000000   2019.000000     12.000000  990000.000000      1.0
#
#        days_listed
# count  51525.00000
# mean      39.55476
# std       28.20427
# min        0.00000
# 25%       19.00000
# 50%       33.00000
# 75%       53.00000
# max      271.00000

# %%
# Memeriksa nilai unik pada beberapa kolom yang berisi nilai berulang
print('Nilai unik kolom is_4w adalah:', df.is_4wd.unique())
print('Nilai unik kolom transmission adalah:', df.transmission.unique())
print('Nilai unik kolom condition adalah:', df.condition.unique())
print('Nilai unik kolom cylinders adalah:', sorted(df.cylinders.unique()))
print('Nilai unik kolom model adalah:', sorted(df.model.unique()))
# Out:
# Nilai unik kolom is_4w adalah: [ 1. nan]
# Nilai unik kolom transmission adalah: ['automatic' 'manual' 'other']
# Nilai unik kolom condition adalah: ['good' 'like new' 'fair' 'excellent' 'salvage' 'new']
# Nilai unik kolom cylinders adalah: [3.0, 4.0, 5.0, 6.0, 8.0, nan, 10.0, 12.0]
# ...

# %% [markdown]
# **Temuan:**
# - Total baris data mencapai 51525. Dari 13 kolom yang ada, terdapat 5 kolom yang memiliki nilai NaN (non-null kurang dari 51525).
# - Kolom `model_year`, `cylinders`, dan `odometer` bertipe float (pecahan), mestinya integer (bulat). Ketiga kolom ini akan diubah tipe datanya.
# - Kolom `date_posted` memuat data tanggal, tetapi memiliki tipe data string. Kolom ini akan diubah tipenya menjadi datetime.
# - Kolom `is_4wd` seharusnya bertipe boolean, angka 1 berarti beroda 4, sedangkan 0 berarti tidak. Sepertinya, angka 0 direpresentasikan oleh nilai NaN, sehingga kolom ini menjadi kolom dengan nilai non-null paling sedikit. Akan kami benahi.
# - Nilai rata-rata (mean) dan median (50%) di kolom `price` dan `days_listed` terpaut cukup jauh, kemungkinan karena ada data outlier.
# - Nilai terendah di kolom `odometer` dan `days_listed` adalah 0. `Odometer` 0 bisa jadi karena kendaraan masih baru, sedangkan `days_listed` 0 agak aneh.
# - Kami memiliki sejumlah nilai unik pada beberapa kolom. Ini bisa digunakan untuk mengategorikan data.

# %% [markdown]
# Secara umum, data yang ada terlihat cukup memadai, tetapi kami perlu membersihkannya terlebih dahulu. Oleh karena itu, di langkah selanjutnya, kami akan melakukan pembersihan data, antara lain mengatasi nilai yang hilang dan mengubah tipe data berdasarkan informasi yang sudah kami identifikasikan di atas.

# %% [markdown]
# ### Mengatasi Nilai-Nilai yang Hilang

# %% [markdown]
# Pada bagian ini, kami akan mengatasi nilai yang hilang pada beberapa kolom.

# %%
# Memeriksa kolom yang memiliki nilai hilang
df.isna().sum()
# Out:
# price               0
# model_year       3619
# model               0
# condition           0
# cylinders        5260
# fuel                0
# odometer         7892
# transmission        0
# type                0
# paint_color      9267
# is_4wd          25953
# date_posted         0
# days_listed         0
# dtype: int64

# %% [markdown]
# Masing-masing kolom dengan nilai yang hilang memiliki karakteristik yang berbeda-beda. Kami tidak dapat menggunakan metode yang sama untuk mengatasi nilai yang hilang pada semua kolom.
#
# Kami akan mulai dari yang mudah, yakni pada kolom `is_4wd` dan `paint_color`.
#
# Kami akan mengisi nilai yang hilang di kolom `is_4wd` dengan 0, lalu  mengubah tipe datanya menjadi boolean. Sebab, kolom ini pada dasarnya hanya berisi nilai ya atau tidak.
#
# Sementara itu, kolom `paint_color` relatif tidak begitu berhubungan dengan kepentingan analisis kami kali ini. Jadi, nilai yang hilang bisa kami isi dengan 'unknown' tanpa mempengaruhi keseluruhan data.

# %%
# Mengatasi nilai hilang di kolom 'is_4wd' dan 'paint_color'
df['is_4wd'] = df['is_4wd'].where(df['is_4wd'] == 1, 0).astype('bool')
df['paint_color'] = df['paint_color'].fillna('unknown')

# %%
# Memeriksa hasil perbaikan
display(df.isna().sum())
df.head()
# Out:
# price              0
# model_year      3619
# model              0
# condition          0
# cylinders       5260
# fuel               0
# odometer        7892
# transmission       0
# type               0
# paint_color        0
# is_4wd             0
# date_posted        0
# days_listed        0
# dtype: int64
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV     unknown    True  2018-06-23           19
# 1    automatic  pickup       white    True  2018-10-19           50
# ...

# %% [markdown]
# Nilai di kolom `paint_color` sudah terisi, demikian pula kolom `is_4wd` juga sudah terisi dan tipe datanya berubah. Selanjutnya, kami akan mengatasi nilai yang hilang di tiga kolom lainnya.
#
# Ketiga kolom lain dengan nilai yang hilang adalah kolom `model_year`, `cylinders`, dan `odometer`. Ketiga kolom ini berguna untuk analisis kami, sehingga kami tidak dapat menghapus kolom ini. Namun, jika kami mengisi nilai yang hilang pada ketiga kolom ini, misalnya dengan median, hasilnya dapat mempengaruhi kejernihan analisis kami.
#
# Selain itu, ketiga kolom ini juga berhubungan dengan kolom lainnya. Misalnya, nilai di `odometer` akan berhubungan dengan kapan kendaraan itu mulai dipasarkan/digunakan (`model_year`, yang mana juga ada nilai hilang di dalamnya) dan kondisinya (`condition`). Kolom `cylinders` juga sangat bergantung pada kolom `model` (yang mana nilai uniknya sangat banyak). Kami bisa saja mengisinya dengan nilai median, tetapi akan menyebabkan pembengkakan data di level median.
#
# Jika mengisi nilai yang hilang pada ketiga kolom ini, kami dapat memperoleh data yang keliru. Oleh karena itu, kami akan menghapus saja semua baris yang berisi nilai hilang pada ketiga kolom ini.

# %%
# Menghapus baris yang masih berisi nilai NaN
df.dropna(inplace=True)
df.reset_index(drop=True, inplace=True)

# %%
# Memeriksa hasilnya
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36419 entries, 0 to 36418
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         36419 non-null  int64
#  1   model_year    36419 non-null  float64
#  2   model         36419 non-null  object
#  3   condition     36419 non-null  object
#  4   cylinders     36419 non-null  float64
#  5   fuel          36419 non-null  object
#  6   odometer      36419 non-null  float64
#  7   transmission  36419 non-null  object
#  8   type          36419 non-null  object
#  9   paint_color   36419 non-null  object
#  10  is_4wd        36419 non-null  bool
#  11  date_posted   36419 non-null  object
#  12  days_listed   36419 non-null  int64
# dtypes: bool(1), float64(3), int64(2), object(7)
# memory usage: 3.4+ MB
#    price  model_year           model  condition  cylinders fuel  odometer  \
# ...

# %% [markdown]
# Kami kehilangan hampir 30 persen data. Namun, data dengan jumlah baris 36419 ini masih tergolong banyak dan cukup representatif untuk kepentingan analisis kami kali ini.

# %% [markdown]
# ### Memperbaiki Tipe Data

# %% [markdown]
# Kami sudah mengatasi nilai yang hilang, sekarang kami akan mengubah tipe data agar sesuai. Berdasarkan informasi sebelumnya, kolom dengan tipe data yang tidak sesuai antara lain yakni `model_year`, `cylinders`, `odometer`, dan `date_posted`.

# %%
# Mengubah tipe data pada kolom yang tidak sesuai
df['model_year'] = df['model_year'].astype('int')
df['cylinders'] = df['cylinders'].astype('int')
df['odometer'] = df['odometer'].astype('int')
df['date_posted'] = pd.to_datetime(df['date_posted'], format='%Y-%m-%d')

# %%
# Memeriksa hasilnya
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36419 entries, 0 to 36418
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         36419 non-null  int64
#  1   model_year    36419 non-null  int32
#  2   model         36419 non-null  object
#  3   condition     36419 non-null  object
#  4   cylinders     36419 non-null  int32
#  5   fuel          36419 non-null  object
#  6   odometer      36419 non-null  int32
#  7   transmission  36419 non-null  object
#  8   type          36419 non-null  object
#  9   paint_color   36419 non-null  object
#  10  is_4wd        36419 non-null  bool
#  11  date_posted   36419 non-null  datetime64[ns]
#  12  days_listed   36419 non-null  int64
# dtypes: bool(1), datetime64[ns](1), int32(3), int64(2), object(6)
# memory usage: 3.0+ MB

# %% [markdown]
# Tipe data kini sudah sesuai.

# %% [markdown]
# ### Memperbaiki Kualitas Data

# %% [markdown]
# Sekarang, kami akan memperbaiki kualitas data dengan menambahkan sejumlah kolom baru yang berguna untuk mempermudah proses analisis selanjutnya

# %%
# Tambahkan nilai waktu dan tanggal pada saat iklan ditayangkan
df['day_posted'] = df['date_posted'].dt.day_name()
df['month_posted'] = df['date_posted'].dt.month_name()
df['year_posted'] = df['date_posted'].dt.year
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1   5500        2013  hyundai sonata   like new          4  gas    110000
# 2  14900        2017    chrysler 200  excellent          4  gas     80903
# 3  14990        2014    chrysler 300  excellent          6  gas     57954
# 4  12990        2015    toyota camry  excellent          4  gas     79212
#
#   transmission   type paint_color  is_4wd date_posted  days_listed day_posted  \
# 0    automatic    SUV     unknown    True  2018-06-23           19   Saturday
# 1    automatic  sedan         red   False  2019-02-07           79   Thursday
# 2    automatic  sedan       black   False  2019-04-02           28    Tuesday
# 3    automatic  sedan       black    True  2018-06-20           15  Wednesday
# 4    automatic  sedan       white   False  2018-12-27           73   Thursday
#
#   month_posted  year_posted
# ...

# %%
# Tambahkan usia kendaraan saat iklan ditayangkan
df['age_year'] = df['year_posted'] - df['model_year']
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1   5500        2013  hyundai sonata   like new          4  gas    110000
# 2  14900        2017    chrysler 200  excellent          4  gas     80903
# 3  14990        2014    chrysler 300  excellent          6  gas     57954
# 4  12990        2015    toyota camry  excellent          4  gas     79212
#
#   transmission   type paint_color  is_4wd date_posted  days_listed day_posted  \
# 0    automatic    SUV     unknown    True  2018-06-23           19   Saturday
# 1    automatic  sedan         red   False  2019-02-07           79   Thursday
# 2    automatic  sedan       black   False  2019-04-02           28    Tuesday
# 3    automatic  sedan       black    True  2018-06-20           15  Wednesday
# 4    automatic  sedan       white   False  2018-12-27           73   Thursday
#
#   month_posted  year_posted  age_year
# ...

# %%
# Tambahkan jarak tempuh rata-rata kendaraan per tahun 
df['mileage_per_year'] = df['odometer'] / df['age_year']
df.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400        2011          bmw x5       good          6  gas    145000
# 1   5500        2013  hyundai sonata   like new          4  gas    110000
# 2  14900        2017    chrysler 200  excellent          4  gas     80903
# 3  14990        2014    chrysler 300  excellent          6  gas     57954
# 4  12990        2015    toyota camry  excellent          4  gas     79212
#
#   transmission   type paint_color  is_4wd date_posted  days_listed day_posted  \
# 0    automatic    SUV     unknown    True  2018-06-23           19   Saturday
# 1    automatic  sedan         red   False  2019-02-07           79   Thursday
# 2    automatic  sedan       black   False  2019-04-02           28    Tuesday
# 3    automatic  sedan       black    True  2018-06-20           15  Wednesday
# 4    automatic  sedan       white   False  2018-12-27           73   Thursday
#
# ...

# %%
# Memeriksa informasi dataset yang baru
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36419 entries, 0 to 36418
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             36419 non-null  int64
#  1   model_year        36419 non-null  int32
#  2   model             36419 non-null  object
#  3   condition         36419 non-null  object
#  4   cylinders         36419 non-null  int32
#  5   fuel              36419 non-null  object
#  6   odometer          36419 non-null  int32
#  7   transmission      36419 non-null  object
#  8   type              36419 non-null  object
#  9   paint_color       36419 non-null  object
#  10  is_4wd            36419 non-null  bool
#  11  date_posted       36419 non-null  datetime64[ns]
#  12  days_listed       36419 non-null  int64
#  13  day_posted        36419 non-null  object
#  14  month_posted      36419 non-null  object
#  15  year_posted       36419 non-null  int64
# ...

# %% [markdown]
# Terdapat satu baris yang hilang di kolom `mileage_per_year `.

# %%
# Memeriksa deskripsi pada kolom `mileage_per_year`
df['mileage_per_year'].describe()
# Out:
# count    3.641800e+04
# mean              inf
# std               NaN
# min      0.000000e+00
# 25%      1.079364e+04
# 50%      1.540000e+04
# 75%      2.275000e+04
# max               inf
# Name: mileage_per_year, dtype: float64

# %% [markdown]
# Kami menemukan nilai NaN dan inf. Kedua hal ini kemungkinan berhubungan. Kami akan lebih dahulu memeriksa nilai inf.
#
# Nilai inf atau infinite biasanya diperoleh karena faktor pembagi, dalam hal ini kolom `age_year`, memiliki nilai 0. Sebab, nilai apapun yang dibagi dengan 0 akan menghasilkan bilangan tidak terhingga (*infinite*).
# Sebelumnya, kolom `age_year` kami dapatkan dari pengurangan pada kolom `year_posted` terhadap `model_year`. Nilai nol di kolom `age_year` kemungkinan terjadi karena kedua kolom tersebut bernilai sama.
#
# Kami akan ubah nilai 0 di kolom `age_year` dengan 1. Kami anggap mobil yang diiklankan di tahun yang sama dengan tahun produksinya memiliki usia 1 tahun.

# %%
# Mengubah nilai 0 di kolom `age_year` menjadi 1
df['age_year'] = df['age_year'].where(df['age_year'] != 0, 1)

# %%
# Memeriksa nilai unik di kolom `age_year`
df['age_year'].unique()
# Out:
# array([  7,   6,   2,   4,   3,   1,  10,   8,  11,  15,  17,  12,  14,
#          5,  24,  18,   9,  26,  19,  13,  22,  16,  38,  20,  44,  21,
#         23,  25,  33,  42,  31,  28,  46,  52,  49,  30,  40,  54,  39,
#         50,  27,  32,  29,  55,  37,  56,  34,  53,  45,  51,  63,  47,
#         48,  41,  36,  35,  57,  71,  59, 110,  82,  60,  58], dtype=int64)

# %% [markdown]
# Sudah tidak ada nilai 0. Kami akan perbaiki kolom `mileage_per_year`.

# %%
# Membuat ulang kolom `mileage_per_year`
df['mileage_per_year'] = df['odometer'] / df['age_year']

# %%
# Memeriksa ulang deskripsi kolom `mileage_per_year`
df['mileage_per_year'].describe()
# Out:
# count     36419.000000
# mean      17998.582847
# std       13368.085264
# min           0.000000
# 25%       10582.292208
# 50%       15041.500000
# 75%       21607.125000
# max      373200.000000
# Name: mileage_per_year, dtype: float64

# %% [markdown]
# Nilai infinite sekarang sudah hilang.

# %%
df['mileage_per_year'].isna().sum()
# Out:
# 0

# %% [markdown]
# Nilai nan juga hilang. Jadi, kolom ini sudah bisa digunakan. Kami berlanjut untuk membuat kolom lainnya.

# %%
# Mengganti nilai pada kolom 'condition' dengan angka agar lebih mudah dimanipulasi 
df['condition_rank'] = df['condition'].replace(['new', 'like new', 'excellent', 'good', 'fair', 'salvage'], [5, 4, 3, 2, 1, 0])

# Menempatkannya pada indeks kolom keempat
df.insert(4, 'condition_rank', df.pop('condition_rank'))
df.head()
# Out:
#    price  model_year           model  condition  condition_rank  cylinders  \
# 0   9400        2011          bmw x5       good               2          6
# 1   5500        2013  hyundai sonata   like new               4          4
# 2  14900        2017    chrysler 200  excellent               3          4
# 3  14990        2014    chrysler 300  excellent               3          6
# 4  12990        2015    toyota camry  excellent               3          4
#
#   fuel  odometer transmission   type paint_color  is_4wd date_posted  \
# 0  gas    145000    automatic    SUV     unknown    True  2018-06-23
# 1  gas    110000    automatic  sedan         red   False  2019-02-07
# 2  gas     80903    automatic  sedan       black   False  2019-04-02
# 3  gas     57954    automatic  sedan       black    True  2018-06-20
# 4  gas     79212    automatic  sedan       white   False  2018-12-27
#
#    days_listed day_posted month_posted  year_posted  age_year  \
# ...

# %%
# Dictionary untuk condition
condition_dict = df[['condition_rank','condition']].drop_duplicates().sort_values('condition_rank').reset_index(drop=True)
condition_dict
# Out:
#    condition_rank  condition
# 0               0    salvage
# 1               1       fair
# 2               2       good
# 3               3  excellent
# 4               4   like new
# 5               5        new

# %% [markdown]
# ### Memeriksa Data yang Sudah Bersih

# %% [markdown]
# Sejauh ini kami sudah melakukan pembersihan dan peningkatan kualitas data. Kami akan memeriksa data sekali lagi sebelum beralih ke proses analisis.

# %%
# Menampilkan informasi/rangkuman umum tentang DataFrame
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36419 entries, 0 to 36418
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             36419 non-null  int64
#  1   model_year        36419 non-null  int32
#  2   model             36419 non-null  object
#  3   condition         36419 non-null  object
#  4   condition_rank    36419 non-null  int64
#  5   cylinders         36419 non-null  int32
#  6   fuel              36419 non-null  object
#  7   odometer          36419 non-null  int32
#  8   transmission      36419 non-null  object
#  9   type              36419 non-null  object
#  10  paint_color       36419 non-null  object
#  11  is_4wd            36419 non-null  bool
#  12  date_posted       36419 non-null  datetime64[ns]
#  13  days_listed       36419 non-null  int64
#  14  day_posted        36419 non-null  object
#  15  month_posted      36419 non-null  object
# ...

# %%
# Menampilkan sampel data 
df.head(10)
# Out:
#    price  model_year                     model  condition  condition_rank  \
# 0   9400        2011                    bmw x5       good               2
# 1   5500        2013            hyundai sonata   like new               4
# 2  14900        2017              chrysler 200  excellent               3
# 3  14990        2014              chrysler 300  excellent               3
# 4  12990        2015              toyota camry  excellent               3
# 5  15990        2013               honda pilot  excellent               3
# 6  11500        2012               kia sorento  excellent               3
# 7  19500        2011  chevrolet silverado 1500  excellent               3
# 8   8990        2012              honda accord  excellent               3
# 9  18990        2012                  ram 1500  excellent               3
#
#    cylinders fuel  odometer transmission    type paint_color  is_4wd  \
# 0          6  gas    145000    automatic     SUV     unknown    True
# ...

# %% [markdown]
# Semua data tampaknya sudah bersih. Kami dapat melanjutkannya ke proses analisis data eksploratif.

# %% [markdown]
# ***

# %% [markdown]
# ## Analisis Data Eksploratif

# %% [markdown]
# ### Mempelajari Parameter Inti

# %% [markdown]
# Sekarang kami memasuki proses analisis data eksploratif terhadap data yang kami miliki. Kami akan menyelidiki sejumlah parameter inti yang akan digunakan untuk analisis lebih lanjut, guna mengetahui karakteristik atau sebaran datanya dan menentukan langkah selanjutnya.
#
# Berikut ini parameter yang akan kami selidiki:
# - Harga (`price`)
# - Usia kendaraan ketika iklan ditayangkan (`age_year`)
# - Jarak tempuh (`odometer`)
# - Jumlah silinder (`cylinders`)
# - Kondisi (`condition_rank`)

# %%
# Membuat visualisasi untuk memeriksa distribusi data pada parameter inti
plt.figure(figsize=(18, 10))

plt.subplot(2, 3, 1)
plt.title('price distribution')
sns.boxplot(x=df['price'])

plt.subplot(2, 3, 2)
plt.title('age distribution')
sns.boxplot(x=df['age_year'])

plt.subplot(2, 3, 3)
plt.title('odometer distribution')
sns.boxplot(x=df['odometer'])

plt.subplot(2, 3, 4)
plt.title('cylinders distribution')
sns.countplot(x=df['cylinders'])

plt.subplot(2, 3, 5)
plt.title('condition distribution')
sns.countplot(x=df['condition_rank'])

plt.show()

# %%
# Menampilkan ulang dictionary untuk condition
condition_dict
# Out:
#    condition_rank  condition
# 0               0    salvage
# 1               1       fair
# 2               2       good
# 3               3  excellent
# 4               4   like new
# 5               5        new

# %% [markdown]
# Temuan:
# - Terdapat outlier yang cukup banyak pada kolom `price`, `age_year`, dan `odometer`. Kami akan mengatasi outlier ini.
# - Jenis silinder kendaraan secara umum terkonsentrasi di jenis 4, 6, dan 8 silinder. Hal ini tidak mengherankan, sebab mayoritas kendaraan yang diproduksi memiliki jumlah silinder 4, 6, atau 8. Meski begitu, masih ada sejumlah kendaraan dengan jumlah silinder yang berbeda di data kami.
# - Mayoritas kendaraan berada pada kualitas yang sedang (*good & excellent*)

# %% [markdown]
# Kami akan menghapus semua outlier. Risikonya yakni jumlah data akan berkurang signifikan. Namun, kami akan memiliki data yang lebih bersih sehingga dapat dianalisis dengan lebih jernih.

# %% [markdown]
# ### Mempelajari dan Menangani Outlier

# %% [markdown]
# Secara umum, data outlier pada ketiga kolom yang kami identifikasikan di atas berada di atas *upper whiskers* dan tidak ada yang berada di bawah *lower whiskers*. Jadi, kami hanya akan membuang data yang berada di atas *upper whiskers*.
#
# Selain itu, di informasi umum data juga telah ditemukan bahwa tidak ada nilai minus. Jadi, *lower whisker* atau batas bawah outlier kami tetapkan dengan 0.
#
# Kami akan membuat dataframe yang baru yang berisi data-data tanpa outlier.

# %%
# Menentukan batas bawah outlier 
lower_whisker = 0

# %%
# Menentukan batas atas outlier 
def upper_whisker (data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    value = Q3 + (1.5 * IQR)
    return value

# %%
# Menentukan upper whisker pada tiga kolom parameter inti
print('Batas atas outlier kolom "price" adalah:', upper_whisker(df, 'price'))
print('Batas atas outlier kolom "age_year" adalah:', upper_whisker(df, 'age_year'))
print('Batas atas outlier kolom "odometer" adalah:', upper_whisker(df, 'odometer'))
# Out:
# Batas atas outlier kolom "price" adalah: 34750.0
# Batas atas outlier kolom "age_year" adalah: 24.0
# Batas atas outlier kolom "odometer" adalah: 282719.0

# %%
# Membuat dataframe baru tanpa outlier
df_new = df[(df['price'] < 34750.0) & (df['age_year'] < 24.0) & (df['odometer'] < 282718.625)].reset_index(drop=True)

# %%
# Memeriksa ukuran dataset baru
df_new.shape
# Out:
# (34226, 19)

# %%
# Menampilkan sampel dataset baru
df.head()
# Out:
#    price  model_year           model  condition  condition_rank  cylinders  \
# 0   9400        2011          bmw x5       good               2          6
# 1   5500        2013  hyundai sonata   like new               4          4
# 2  14900        2017    chrysler 200  excellent               3          4
# 3  14990        2014    chrysler 300  excellent               3          6
# 4  12990        2015    toyota camry  excellent               3          4
#
#   fuel  odometer transmission   type paint_color  is_4wd date_posted  \
# 0  gas    145000    automatic    SUV     unknown    True  2018-06-23
# 1  gas    110000    automatic  sedan         red   False  2019-02-07
# 2  gas     80903    automatic  sedan       black   False  2019-04-02
# 3  gas     57954    automatic  sedan       black    True  2018-06-20
# 4  gas     79212    automatic  sedan       white   False  2018-12-27
#
#    days_listed day_posted month_posted  year_posted  age_year  \
# ...

# %%
# Memeriksa visualisasi parameter inti pada dataset baru
plt.figure(figsize=(18, 10))

plt.subplot(2, 3, 1)
plt.title('price distribution')
sns.boxplot(x=df_new['price'])

plt.subplot(2, 3, 2)
plt.title('age distribution')
sns.boxplot(x=df_new['age_year'])

plt.subplot(2, 3, 3)
plt.title('odometer distribution')
sns.boxplot(x=df_new['odometer'])

plt.subplot(2, 3, 4)
plt.title('cylinders distribution')
sns.countplot(x=df_new['cylinders'])

plt.subplot(2, 3, 5)
plt.title('condition distribution')
sns.countplot(x=df_new['condition_rank'])

plt.show()

# %% [markdown]
# Pada data yang baru masih terlihat ada sedikit datapoint yang berada di luar upper whisker. Hal ini wajar karena perubahan ukuran data. Kami akan mempertahankannya saja. Data yang baru kini memiliki tiga kolom parameter inti yang lebih bersih, tetapi jumlah barisnya berkurang menjadi 34226. Meski begitu, jumlah ini masih mencukupi untuk kebutuhan analisis kami.

# %% [markdown]
# ### Mempelajari Parameter Inti Tanpa Outlier

# %% [markdown]
# Kami akan membandingkan data yang masih memiliki outlier (df) dengan yang sudah bersih (df_new). Kami akan fokus pada tiga parameter inti yang tadinya memiliki outlier.

# %%
# Membandingkan visualisasi distribusi data pada tiga kolom parameter inti antara df dan df_new
plt.figure(figsize=(12, 18))

plt.subplot(3, 2, 1)
plt.title('price distribution old')
sns.boxplot(x=df['price'])

plt.subplot(3, 2, 2)
plt.title('price distribution new')
sns.boxplot(x=df_new['price'])

plt.subplot(3, 2, 3)
plt.title('age distribution old')
sns.boxplot(x=df['age_year'])

plt.subplot(3, 2, 4)
plt.title('age distribution new')
sns.boxplot(x=df_new['age_year'])

plt.subplot(3, 2, 5)
plt.title('odometer distribution old')
sns.boxplot(x=df['odometer'])

plt.subplot(3, 2, 6)
plt.title('odometer distribution new')
sns.boxplot(x=df_new['odometer'])

plt.show()

# %% [markdown]
# Perbedaan antara data lama (kiri) yang masih memiliki outlier dengan data baru (kanan) yang sudah bersih tampak cukup mencolok.

# %%
# Membandingkan deskripsi kedua dataset
print('Deskripsi Data Lama')
display(df.describe())
print('Deskripsi Data Baru')
display(df_new.describe())
# Out:
# Deskripsi Data Lama
#                price    model_year  condition_rank     cylinders  \
# count   36419.000000  36419.000000    36419.000000  36419.000000
# mean    12187.675417   2009.753425        2.637003      6.132596
# std     10076.739680      6.265305        0.713758      1.659646
# min         1.000000   1908.000000        0.000000      3.000000
# 25%      5000.000000   2006.000000        2.000000      4.000000
# 50%      9000.000000   2011.000000        3.000000      6.000000
# 75%     16900.000000   2014.000000        3.000000      8.000000
# max    375000.000000   2019.000000        5.000000     12.000000
#
#             odometer   days_listed   year_posted      age_year  \
# count   36419.000000  36419.000000  36419.000000  36419.000000
# mean   115323.632747     39.649798   2018.306324      8.598424
# std     65068.650067     28.119391      0.460972      6.218145
# min         0.000000      0.000000   2018.000000      1.000000
# ...

# %% [markdown]
# Informasi umum antara kedua dataframe juga berubah. Jumlah data berkurang dari 36418 menjadi 34226 baris. Data rata-rata (mean) dan median (50%) pun bergeser menjadi lebih rendah. Nilai minimum (min) tetap sama, tetapi nilai maksimum (max) berkurang signifikan.

# %% [markdown]
# ### Masa Berlaku Iklan

# %% [markdown]
# Sekarang kami akan menyelidiki kolom `days_listed` dari data yang baru untuk mengukur seberapa lama iklan ditayangkan.

# %%
# Memeriksa deskripsi kolom `days_listed
df_new['days_listed'].describe()
# Out:
# count    34226.000000
# mean        39.630515
# std         28.123050
# min          0.000000
# 25%         19.000000
# 50%         33.000000
# 75%         53.000000
# max        271.000000
# Name: days_listed, dtype: float64

# %%
# Memeriksa nilai yang paling banyak muncul pada kolom `days_listed`
df_new['days_listed'].mode()
# Out:
# 0    24
# Name: days_listed, dtype: int64

# %%
# Menghitung jumlah baris dengan nilai 24 pada kolom `days_listed`
df_new[df_new['days_listed'] == 24]['days_listed'].count()
# Out:
# 655

# %% [markdown]
# Secara rata-rata (mean), iklan ditayangkan selama hampir 40 hari sebelum kendaraan laku terjual atau iklan diturunkan, sedangkan mayoritas iklan tayang selama 24 hari (mode), yakni mencapai 655 iklan.
#
# Waktu paling cepat (min) iklan ditayangkan adalah 0 hari, bisa jadi karena segera dihapus atau batal tayang. Sementara itu, waktu terlama (max) mencapai 271 hari atau sekitar 9 bulan. Kami akan cek persebaran datanya.

# %%
# Memeriksa visualisasi masa berlaku iklan
plt.hist(df_new['days_listed'])
plt.show()

# %%
# Memeriksa outlier 
sns.boxplot(x=df_new['days_listed'])
plt.show()

# %% [markdown]
# Mayoritas iklan tayang selama kurang dari 50 hari saja. Terdapat cukup banyak data yang dianggap sebagai outlier di sini.
#
# Lama atau singkatnya penayangan iklan bisa jadi sangat bergantung pada harga kendaraan, jenis, kondisi, atau usianya. Ini memberi kita gambaran umum tentang kinerja iklan kendaraan sejauh ini.

# %% [markdown]
# ### Harga Rata-Rata Setiap Jenis Kendaraan

# %% [markdown]
# Selanjutnya, kami akan menghitung jumlah iklan dan rata-rata harga untuk tiap jenis kendaraan. Kami juga menyelidiki hubungan ketergantungan antara jumlah iklan pada jenis kendaraan. Nantinya, kami akan memilih dua jenis kendaraan dengan jumlah iklan paling banyak.

# %%
# Membuat tabel baru dengan kolom harga rata-rata dan jumlah iklan
mean_price = df_new.pivot_table(index='type', values='price', aggfunc=['mean', 'count'])
mean_price.columns = ['average_price', 'number_of_list']
mean_price.sort_values(by='number_of_list', ascending=False)
# Out:
#              average_price  number_of_list
# type
# sedan          6984.115571            8445
# SUV           10531.326681            8418
# truck         15057.539104            7902
# pickup        15202.944194            4444
# coupe         13437.230345            1450
# wagon          8886.777568            1061
# mini-van       8171.119804             818
# hatchback      6685.497878             707
# van            9031.925301             415
# convertible   13118.281124             249
# other         10586.310559             161
# offroad       14458.528986             138
# bus           16293.666667              18

# %%
# Menghitung korelasi antara kedua kolom
mean_price['average_price'].corr(mean_price['number_of_list'])
# Out:
# -0.03896121723736776

# %% [markdown]
# Jenis kendaraan yang paling banyak diiklankan tidak berbanding lurus dengan harganya. Kendaraan yang rata-rata harganya paling mahal atau paling murah tidak menjadi kendaraan yang paling banyak diiklankan. Korelasi antara keduanya sangat rendah (-0,04).

# %%
# Memeriksa visualisasi jumlah iklan per jenis kendaraan 
mean_price['number_of_list'].sort_values().plot(style='o')
plt.show()

# %% [markdown]
# Berdasarkan grafik ini, terlihat bahwa terjadi lompatan yang signifikan pada jumlah iklan dari tiga tipe teratas dibanding tipe-tipe lainnya. Kami akan fokuskan analisis selanjutnya pada dua jenis dengan jumlah iklan teratas, yakni sedan dan SUV.

# %% [markdown]
# ### Faktor Harga

# %% [markdown]
# Kini kami akan melakukan analisis untuk mengamati faktor-faktor yang paling mempengaruhi harga kendaraan. Kami akan memfokuskan analisis ini pada dua tipe kendaraan yang paling populer, yakni sedan dan SUV.
#
# Kami akan mengukur sejauh mana korelasi antara harga kendaraan pada kedua tipe ini dengan parameter usia (`age_year`), jarak tempuh (`odometer`), kondisi (`condition_rank`), tipe transmisi (`transmission`), dan warnanya (`paint_color`).
#
# Kami akan melakukan analisis untuk jenis sedan, selanjutnya untuk SUV.

# %% [markdown]
# #### Sedan

# %%
# Membuat dataframe baru khusus sedan
df_sedan = df_new[df_new['type'] == 'sedan'].reset_index(drop=True)
df_sedan = df_sedan[['price','age_year', 'odometer', 'condition_rank', 'transmission', 'paint_color']]
df_sedan.head()
# Out:
#    price  age_year  odometer  condition_rank transmission paint_color
# 0   5500         6    110000               4    automatic         red
# 1  14900         2     80903               3    automatic       black
# 2  14990         4     57954               3    automatic       black
# 3  12990         3     79212               3    automatic       white
# 4   8990         7    111142               3    automatic        grey

# %%
# Menganalisis korelasi parameter dengan harga
df_sedan.corr()['price']
# Out:
# price             1.000000
# age_year         -0.639002
# odometer         -0.556728
# condition_rank    0.296588
# Name: price, dtype: float64

# %%
# Menganalisis korelasi harga dan usia kendaraan
df_sedan.plot(x='age_year', y='price', kind='scatter', alpha=0.5) 
plt.show()

# %%
# Menganalisis korelasi harga dan jarak tempuh kendaraan
df_sedan.plot(x='odometer', y='price', kind='scatter', alpha=0.5) 
plt.show()

# %%
# Menganalisis korelasi harga dan kondisi kendaraan
df_sedan.plot(x='condition_rank', y='price', kind='scatter', alpha=0.5) 
plt.show()

# %% [markdown]
# Berdasarkan analisis korelasi ini, harga kendaraan sedan memiliki korelasi negatif yang cukup kuat dengan usia kendaraan dan jarak tempuh. Makin tinggi usia atau jarak tempuh, makin rendah harganya.
#
# Sebaliknya, korelasi harga dengan kondisi bersifat positif, tetapi lemah. Peningkatan kualitas kendaraan tidak otomatis menyebabkan harganya turut meningkat. Harga kendaraan terlihat tinggi pada kualitas sedang (2, 3, 4), tetapi relatif rendah pada kualitas tinggi (5).
#
# Selanjutnya, kami akan periksa korelasi pada variabel kategorik tipe transmisi (`transmission`) dan warna (`paint_color`).

# %% [markdown]
# Kami akan periksa dulu jumlah baris iklan pada masing-masing variabel. Kami membutuhkan setidaknya 50 baris iklan untuk masing-masing kategori di kedua variabel ini agar analisis ini menjadi lebih valid.

# %%
# Memeriksa jumlah masing-masing value pada kolom `transmission`
df_sedan['transmission'].value_counts()
# Out:
# automatic    7930
# manual        410
# other         105
# Name: transmission, dtype: int64

# %%
# Memeriksa jumlah masing-masing value pada kolom `paint_color`
df_sedan['paint_color'].value_counts()
# Out:
# unknown    1514
# silver     1426
# black      1231
# grey       1142
# white      1073
# blue        859
# red         662
# custom      197
# brown       169
# green       136
# purple       17
# yellow       12
# orange        7
# Name: paint_color, dtype: int64

# %% [markdown]
# Kolom `transmission` tampaknya cukup memadai, tetapi kolom `paint_color` memiliki tiga kategori yang tidak memenuhi syarat, yakni purple, yellow, dan orange. Kami akan kecualikan ketiga kelompok tersebut.

# %%
# Korelasi harga dengan variabel transmisi
plt.figure(figsize=(12,7))
sns.boxplot(data=df_sedan, x='price', y='transmission')
plt.show()

# %% [markdown]
# Terlihat bahwa kendaraan dengan transmisi otomatis cenderung memiliki harga lebih tinggi dibanding transmisi manual dan jenis transmisi lainnya.

# %%
# Korelasi harga dengan variabel warna
sedan_color = df_sedan[~df_sedan['paint_color'].isin(['purple', 'yellow', 'orange'])]
plt.figure(figsize=(12,7))
sns.boxplot(data=sedan_color, x='price', y='paint_color')
plt.show()

# %% [markdown]
# Korelasi harga dengan warna kendaraan relatif rendah. Tidak banyak perbedaan harga antara warna yang satu dengan yang lain.
#
# Mari lanjutkan pada jenis kendaraan berikutnya, yakni SUV. Kami akan mengulang proses yang sama.

# %% [markdown]
# #### SUV

# %%
# Membuat dataframe baru khusus SUV
df_suv = df_new[df_new['type'] == 'SUV'].reset_index(drop=True)
df_suv = df_new[['price','age_year', 'odometer', 'condition_rank', 'transmission', 'paint_color']]
df_suv.head()
# Out:
#    price  age_year  odometer  condition_rank transmission paint_color
# 0   9400         7    145000               2    automatic     unknown
# 1   5500         6    110000               4    automatic         red
# 2  14900         2     80903               3    automatic       black
# 3  14990         4     57954               3    automatic       black
# 4  12990         3     79212               3    automatic       white

# %%
# Mengukur korelasi sejumlah parameter dengan harga
df_suv.corr()['price']
# Out:
# price             1.000000
# age_year         -0.533737
# odometer         -0.435377
# condition_rank    0.186926
# Name: price, dtype: float64

# %%
# Korelasi harga dan usia kendaraan
df_suv.plot(x='age_year', y='price', kind='scatter', alpha=0.5) 
plt.show()

# %%
# Korelasi harga dan jarak tempuh kendaraan
df_suv.plot(x='odometer', y='price', kind='scatter', alpha=0.5)
plt.show()

# %%
# Korelasi harga dan kondisi kendaraan
df_suv.plot(x='condition_rank', y='price', kind='scatter', alpha=0.5) 
plt.show()

# %% [markdown]
# Pola korelasi pada mobil tipe SUV ini relatif sama dengan tipe sedan yang sebelumnya telah kami analisis. Namun, tingkat korelasinya terlihat lebih rendah dibanding tipe sedan. Kolom `age_year` memiliki korelasi -0.533737, kolom `odometer` hanya -0.435377, dan kolom `condition_rank` hanya 0.186926.
#
# Di kolom `condition_rank`, polanya juga relatif mirip, yakni kendaraan dengan kualitas menengah justru cenderung lebih tinggi harganya.
#
# Kami akan periksa, apakah hal yang sama juga berlaku untuk korelasi pada variabel kategorik tipe transmisi (`transmission`) dan warna (`paint_color`). Kami akan periksa dulu kelayakan variabelnya (lebih dari 50 baris iklan atau tidak).

# %%
# Memeriksa jumlah masing-masing value pada kolom `transmission`
df_suv['transmission'].value_counts()
# Out:
# automatic    31250
# manual        1732
# other         1244
# Name: transmission, dtype: int64

# %%
# Memeriksa jumlah masing-masing value pada kolom `paint_color`
df_suv['paint_color'].value_counts()
# Out:
# white      6576
# unknown    6110
# black      5105
# silver     4272
# grey       3412
# blue       2977
# red        2937
# green       887
# custom      788
# brown       788
# yellow      162
# orange      148
# purple       64
# Name: paint_color, dtype: int64

# %% [markdown]
# Tampaknya tidak ada masalah, semua kategori memiliki data di atas 50 baris. Kami akan lanjutkan analisisnya.

# %%
# Korelasi harga dengan variabel transmisi
plt.figure(figsize=(12,7))
sns.boxplot(data=df_suv, x='price', y='transmission')
plt.show()

# %%
# Korelasi harga dengan variabel warna
plt.figure(figsize=(12,7))
sns.boxplot(data=df_suv, x='price', y='paint_color')
plt.show()

# %% [markdown]
# Tampaknya, di tipe SUV ini, variable kategorik memiliki pengaruh yang cukup besar terhadap faktor harga. Kendaraan dengan tipe transmisi 'other' memiliki median tingkat harga yang jauh lebih tinggi dibanding tipe transmisi automatic dan manual. Sementara itu, untuk kategori warna, orange dan yellow memiliki tingkat harga yang secara umum lebih tinggi dibanding warna lainnya.

# %% [markdown]
# ## Kesimpulan Umum

# %% [markdown]
# Kami telah selesai melakukan analisis data eksploratif untuk mengukur faktor-faktor yang menentukan harga suatu kendaraan dengan bermodalkan data yang kami peroleh dari pengiklanan di Crankshaft List.
#
# Selama proses ini, kami telah membersihkan data dengan mengisi sebagian nilai yang hilang dan memangkas yang lainnya. Hal ini dilakukan agar data yang ada dapat benar-benar representatif. Pada akhirnya, analisis kami mengerucut pada dua tipe kendaraan yang paling banyak diiklankan di Crankshaft List, yakni sedan dan SUV.
#
# Analisis ini berhasil menemukan bahwa harga suatu kendaraan yang diiklankan di Crankshaft List memiliki korelasi yang cukup kuat dengan usia kendaraan dan jarak tempuh, serta korelasi yang relatif lemah dengan kondisi kendaraan. Namun, secara umum tingkat korelasinya lebih kuat pada model sedan ketimbang model SUV.
#
# Sementara itu, untuk variable kategorik berupa transmisi dan warna, ada perbedaan pola di antara sedan dan SUV.
#
# Pada kategori transmisi, tipe sedan cenderung lebih mahal pada jenis transmisi otomatis dan paling murah pada transmisi 'other'. Sebaliknya, pada tipe SUV, transmisi 'other' justru menjadi yang paling mahal.
#
# Perbedaan juga terlihat pada kategori warna. Secara umum, pada tipe sedan, warna kendaraan tidak begitu mempengaruhi harga, tetapi pada tipe SUV terdapat jenis warna yang memiliki harga jauh lebih tinggi ketimbang yang lain.
#
# Dari analisis ini, kami dapat cukup yakin untuk mengatakan bahwa faktor usia kendaraan dan jarak tempuh menjadi faktor yang paling berpengaruh pada harga kendaraan yang diiklankan di Crankshaft List. Sementara itu, faktor lainnya seperti kondisi kendaraan, jenis transmisi, dan warna kendaraan relatif rendah pengaruhnya.
